# %% [markdown]
# <h1>Выпуски спецификации</h1>

# %%
import pandas as pd
import numpy as np
import pyodbc 

db_conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-JSR6TV0G;'
                      'Database=Pro_t_londonSQL;'
                      'Trusted_Connection=yes;')

# %%
df = pd.read_sql_query('SELECT * FROM Pro_t_londonSQL.dbo.ВыпСпец', db_conn)
df.shape
# Out:
# (3861, 6)

# %%
df.head()
# Out:
#    код_марки  выпуск  дата_созд  прим  текущий  вкл_вып
# 0       1910       0 2009-04-02  None        1     True
# 1       1895       0 2009-04-02  None        1     True
# 2       1888       0 2009-04-02  None        1     True
# 3       1912       0        NaT  None        1     True
# 4       1903       0 2009-04-03  None        1     True

# %%
df = df.replace("", np.nan)

# %%
df.isna().sum()
# Out:
# код_марки       0
# выпуск          0
# дата_созд    2554
# прим         3816
# текущий         0
# вкл_вып         0
# dtype: int64

# %% [markdown]
# <h2>Имеется примечание</h2>

# %%
df[df["прим"].isna() == False]
# Out:
#       код_марки  выпуск  дата_созд                            прим  текущий  \
# 144        2001       1 2010-05-19              Разрешение 2384-10        1
# 287        2081       1 2009-11-06       Усиление южной рамы копра        1
# 290        2081       2 2009-11-16     реконструкция копра (общая)        0
# 302        2092       0 2009-11-19                             смс        0
# 303        2092       2 2009-11-19                             см2        1
# 324        2106       0 2009-12-02                             см1        1
# 325        2108       0 2009-12-02                             смс        1
# 478        2362       0        NaT                               1        1
# 549        2083       1 2010-09-17  металл по новым воротам (изм1)        1
# 1140       3005       0        NaT                               1        1
# 1146       3011       0        NaT                               1        1
# 1209       2990       2 2012-10-15                           ДАМИР        1
# 1651       3298       1 2013-10-22                  по изменению 2        0
# 2769       4638       1 2016-07-11                             СМ1        0
# 2770       4638       2 2016-12-12                             СМ2        0
# 2772       4639       1 2016-07-11                             СМ1        0
# 2773       4639       2 2016-12-12                             СМ2        0
# 2823       4687       1 2016-07-11                             СМ1        0
# 2824       4687       2 2016-12-12                             СМ2        0
# 2826       4688       1 2016-07-11                             СМ1        0
# 2827       4688       2 2016-12-12                             СМ2        0
# 2829       4689       1 2016-07-11                             СМ1        0
# 2830       4689       2 2016-12-12                             СМ2        0
# 2832       4690       1 2016-07-11                             СМ1        0
# 2833       4690       2 2016-12-12                             СМ2        0
# 2994       4842       2 2018-03-01                          изм. 3        0
# 3178       5008       2 2018-06-08                           минус        1
# 3219       5047       0        NaT                       до изм. 1        0
# 3226       5054       0        NaT                  до изменения 2        0
# 3465       5259       1        NaT                           Новый        1
# 3466       5259       2 2019-05-15                        демонтаж        0
# 3467       5259       0 2019-05-17                          Старый        0
# 3478       5054       1 2019-06-14                     изменение 2        1
# 3487       5047       1 2019-07-01                       по изм. 1        1
# 3489       5275       0        NaT                  до изменения 2        0
# 3490       5275       1 2019-06-14                     изменение 2        1
# 3497       5280       1 2019-07-15                          Mc-KM3        1
# 3511       5293       1 2019-07-15                          Mc-KM3        0
# 3621       5238       1 2019-12-12                Изменение по КМД        0
# 3632       5399       0        NaT                  минус демонтаж        0
# 3633       4803       1 2019-12-28              минус монтаж изм.2        0
# 3634       4803       2 2019-12-28             для сметы по изм. 2        1
# 3637       5399       1 2020-01-14                  металл эскизов        1
# 3688       5445       1 2020-01-14                           Новый        1
# 3690       5445       2 2020-03-19                     Примененный        0
#
#       вкл_вып
# 144      True
# 287      True
# 290      True
# 302      True
# 303      True
# 324      True
# 325      True
# 478      True
# 549      True
# 1140     True
# 1146     True
# 1209     True
# 1651     True
# 2769     True
# 2770     True
# 2772     True
# 2773     True
# 2823     True
# 2824     True
# 2826     True
# 2827     True
# 2829     True
# 2830     True
# 2832     True
# 2833     True
# 2994     True
# 3178     True
# 3219    False
# 3226    False
# 3465     True
# 3466    False
# 3467     True
# 3478     True
# 3487     True
# 3489     True
# 3490     True
# 3497     True
# 3511     True
# 3621    False
# 3632    False
# 3633    False
# 3634     True
# 3637     True
# 3688     True
# 3690    False

# %% [markdown]
# <h2>Удаляем дубликаты</h2>

# %%
df = df.drop_duplicates(subset=["код_марки", "выпуск"])
df.shape
# Out:
# (3861, 6)

# %% [markdown]
# <h2>Удаляем вкл_вып (?)</h2>

# %%
df = df.drop(["вкл_вып"], axis=1)
df.head()
# Out:
#    код_марки  выпуск  дата_созд  прим  текущий
# 0       1910       0 2009-04-02  None        1
# 1       1895       0 2009-04-02  None        1
# 2       1888       0 2009-04-02  None        1
# 3       1912       0        NaT  None        1
# 4       1903       0 2009-04-03  None        1

# %% [markdown]
# <h2>Исследуем данные</h2>

# %%
df["выпуск"].value_counts()
# Out:
# 0    3598
# 1     218
# 2      41
# 3       4
# Name: выпуск, dtype: int64

# %%
df["дата_созд"].max()
# Out:
# Timestamp('2020-10-01 00:00:00')

# %%
df["дата_созд"].min()
# Out:
# Timestamp('2009-04-02 00:00:00')

# %%
df["текущий"].value_counts()
# Out:
# 1    3612
# 0     249
# Name: текущий, dtype: int64

# %%
df["текущий"] = df["текущий"].map(lambda x: True if (x == 1) else False)

# %% [markdown]
# <h2>Добавляем id</h2>

# %%
df.insert(0, 'id', range(1, len(df) + 1))

# %% [markdown]
# <h2>Меняем названия столбцов</h2>

# %%
df = df.rename(columns={"код_марки": "mark_id",
                        "выпуск": "num",
                        "дата_созд": "created_date",
                        "текущий": "is_current",
                        "прим": "note"
                       })
df
# Out:
#         id  mark_id  num created_date  note  is_current
# 0        1     1910    0   2009-04-02  None        True
# 1        2     1895    0   2009-04-02  None        True
# 2        3     1888    0   2009-04-02  None        True
# 3        4     1912    0          NaT  None        True
# 4        5     1903    0   2009-04-03  None        True
# ...    ...      ...  ...          ...   ...         ...
# 3856  3857     5603    1   2020-10-01  None        True
# 3857  3858     5604    0          NaT  None        True
# 3858  3859     5604    1   2020-01-20  None       False
# 3859  3860     5605    0          NaT  None        True
# 3860  3861     5606    0          NaT  None        True
#
# [3861 rows x 6 columns]

# %% [markdown]
# <h2>Null для бд</h2>

# %%
df["created_date"] = df["created_date"].astype(object).where(df["created_date"].notnull(), None)
df = df.where(pd.notnull(df), None)

# %%
df.head()
# Out:
#    id  mark_id  num         created_date  note  is_current
# 0   1     1910    0  2009-04-02 00:00:00  None        True
# 1   2     1895    0  2009-04-02 00:00:00  None        True
# 2   3     1888    0  2009-04-02 00:00:00  None        True
# 3   4     1912    0                 None  None        True
# 4   5     1903    0  2009-04-03 00:00:00  None        True

# %%
m_ids = pd.read_csv("mark_ids.csv")
m_ids = m_ids.drop(["Unnamed: 0"], axis=1)
m_ids = m_ids.values.flatten().tolist()

# %%
df = df[df["mark_id"].isin(m_ids)]
df
# Out:
#         id  mark_id  num         created_date  note  is_current
# 1325  1326     3173    0                 None  None        True
# 1327  1328     3175    0                 None  None        True
# 1404  1405     3252    0                 None  None        True
# 2029  2030     3877    0                 None  None        True
# 2267  2268     4120    0                 None  None       False
# ...    ...      ...  ...                  ...   ...         ...
# 3843  3844     5593    0                 None  None        True
# 3844  3845     5594    0                 None  None        True
# 3845  3846     5595    0                 None  None        True
# 3846  3847     5595    1  2020-01-20 00:00:00  None       False
# 3847  3848     5596    0  2020-09-16 00:00:00  None        True
#
# [1334 rows x 6 columns]

# %% [markdown]
# <h1>Postgres</h1>

# %% [markdown]
# <h2>Создание таблицы</h2>

# %%
from psycopg2 import connect, sql, DatabaseError
import psycopg2.extras as extras

# %% [markdown]
# DocumentsKM

# %%
# Connect
try:
    conn = connect (
        dbname = "documentskm",
        user = "postgres",
        host = "localhost",
        password = "password"
    )
    cursor = conn.cursor()
except Exception as err:
    cursor = None
    print("Psycopg2 error:", err)
    
# Check if the connection was valid
if cursor != None:
    print("Connection successful")
# Out:
# Connection successful

# %%
cursor.execute(open("sql/3.sql", "r").read())
conn.commit()

# %% [markdown]
# <h2>Вставка данных</h2>

# %%
def execute_values(conn, df, table):
    tuples = [tuple(x) for x in df.to_numpy()]
    cols = ','.join(list(df.columns))
    query  = "INSERT INTO %s(%s) VALUES %%s" % (table, cols)
    cursor = conn.cursor()
    try:
        extras.execute_values(cursor, query, tuples)
        conn.commit()
    except (Exception, DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_values() done")
    cursor.close()

# %%
execute_values(conn, df, "specifications")
# Out:
# execute_values() done
