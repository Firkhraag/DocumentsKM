# %% [markdown]
# <h1>Виды ссылочных документов (+)</h1>

# %%
import pandas as pd
import numpy as np
import pyodbc 

db_conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-JSR6TV0G;'
                      'Database=Pro_t_londonSQL;'
                      'Trusted_Connection=yes;')

# %%
df = pd.read_sql_query('SELECT * FROM Pro_t_londonSQL.dbo.Спр_ссыл_в', db_conn)
df.shape
# Out:
# (29, 2)

# %%
df
# Out:
#     Вид_сд               Наим_вида
# 0        1                 Колонны
# 1        2         Стойки фахверка
# 2        3                   Стены
# 3        4             Перегородки
# 4        5                    Полы
# 5        6                 Потолки
# 6        7                Покрытия
# 7        8       Подкрановые балки
# 8        9                 Прогоны
# 9       10                    Окна
# 10      11                   Двери
# 11      12                  Ворота
# 12      13      Лестницы, площадки
# 13      14                  Фонари
# 14      15                    Узлы
# 15      16    Конструкции каркасов
# 16      17                 Стаканы
# 17      18         Эстакады, опоры
# 18      19       Крановые эстакады
# 19      20  Транспортерные галереи
# 20      21          Вытяжные башни
# 21      22   Опоры воздушных линий
# 22      23              Резервуары
# 23      24                    Баки
# 24      25          Лифты грузовые
# 25      26    СПРАВОЧНЫЕ МАТЕРИАЛЫ
# 26      27    существующие проекты
# 27      28         Поворотные щиты
# 28      29                  Прочее

# %%
df["Наим_вида"] = df["Наим_вида"].str.strip()
df["Наим_вида"] = df["Наим_вида"].str.capitalize()

# %%
df = df.drop_duplicates(subset=["Наим_вида"])
df
# Out:
#     Вид_сд               Наим_вида
# 0        1                 Колонны
# 1        2         Стойки фахверка
# 2        3                   Стены
# 3        4             Перегородки
# 4        5                    Полы
# 5        6                 Потолки
# 6        7                Покрытия
# 7        8       Подкрановые балки
# 8        9                 Прогоны
# 9       10                    Окна
# 10      11                   Двери
# 11      12                  Ворота
# 12      13      Лестницы, площадки
# 13      14                  Фонари
# 14      15                    Узлы
# 15      16    Конструкции каркасов
# 16      17                 Стаканы
# 17      18         Эстакады, опоры
# 18      19       Крановые эстакады
# 19      20  Транспортерные галереи
# 20      21          Вытяжные башни
# 21      22   Опоры воздушных линий
# 22      23              Резервуары
# 23      24                    Баки
# 24      25          Лифты грузовые
# 25      26    Справочные материалы
# 26      27    Существующие проекты
# 27      28         Поворотные щиты
# 28      29                  Прочее

# %% [markdown]
# <h2>Rename columns</h2>

# %%
df = df.rename(columns={"Вид_сд": "id",
                        "Наим_вида": "name"
                       })
df
# Out:
#     id                    name
# 0    1                 Колонны
# 1    2         Стойки фахверка
# 2    3                   Стены
# 3    4             Перегородки
# 4    5                    Полы
# 5    6                 Потолки
# 6    7                Покрытия
# 7    8       Подкрановые балки
# 8    9                 Прогоны
# 9   10                    Окна
# 10  11                   Двери
# 11  12                  Ворота
# 12  13      Лестницы, площадки
# 13  14                  Фонари
# 14  15                    Узлы
# 15  16    Конструкции каркасов
# 16  17                 Стаканы
# 17  18         Эстакады, опоры
# 18  19       Крановые эстакады
# 19  20  Транспортерные галереи
# 20  21          Вытяжные башни
# 21  22   Опоры воздушных линий
# 22  23              Резервуары
# 23  24                    Баки
# 24  25          Лифты грузовые
# 25  26    Справочные материалы
# 26  27    Существующие проекты
# 27  28         Поворотные щиты
# 28  29                  Прочее

# %% [markdown]
# <h1>Postgres</h1>

# %%
from psycopg2 import connect, sql, DatabaseError
import psycopg2.extras as extras

# %%
# Connect
try:
    conn = connect (
        dbname = "documentskm",
        user = "postgres",
        host = "localhost",
        password = "password"
    )
    cursor = conn.cursor()
except Exception as err:
    cursor = None
    print("Psycopg2 error:", err)
    
# Check if the connection was valid
if cursor != None:
    print("Connection successful")
# Out:
# Connection successful

# %%
cursor.execute(open("sql/40.sql", "r").read())
conn.commit()

# %% [markdown]
# <h2>Insert data</h2>

# %%
def execute_values(conn, df, table):
    tuples = [tuple(x) for x in df.to_numpy()]
    cols = ','.join(list(df.columns))
    query  = "INSERT INTO %s(%s) VALUES %%s" % (table, cols)
    cursor = conn.cursor()
    try:
        extras.execute_values(cursor, query, tuples)
        conn.commit()
    except (Exception, DatabaseError) as error:
        print("Error: %s" % error)
        conn.rollback()
        cursor.close()
        return 1
    print("execute_values() done")
    cursor.close()

# %%
execute_values(conn, df, "linked_doc_types")
# Out:
# execute_values() done
